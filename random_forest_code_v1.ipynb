# %%
##Import data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import sklearn.metrics as metrics
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

#import data
nhl = pd.read_excel("/Users/expctchaos/Documents/HSG-Python-Project/NHL data.xlsx")
nhl.info()

##Prepare data

#Eliminate rows in dataset with missing data
nhl=nhl.dropna()
nhl.info()

#add Goals per Game
nhl["G/GP"] = nhl["G"]/nhl["GP"]

#add Assist per Game
nhl["A/GP"] = nhl["A"]/nhl["GP"]

#add the year the players were born
nhl['BornInt'] = nhl['Born'].str.replace('\W', '', regex=True)
nhl=nhl.dropna()
nhl = nhl.astype({'BornInt':'int'})
conditions = [
    (nhl['BornInt'] < 10000),
    (nhl['BornInt'] >= 10000) & (nhl['BornInt'] < 100000),
    (nhl['BornInt'] >= 100000)]
choices = [2000,nhl['BornInt']//10000+2000, nhl['BornInt']//10000+1900]
nhl['YearBorn'] = np.select(conditions, choices)
del nhl['BornInt']

#add players age
nhl["age"] = 2022 - nhl['YearBorn']

#add BMI (Body Mass Index)
nhl = nhl.astype({'Ht':'int'})
nhl = nhl.astype({'Wt':'int'})
nhl["WtInKg"] = nhl["Wt"]*0.453592
nhl["HtInCm"] = nhl["Ht"]*2.54
nhl["HtInCm^2"] = nhl["HtInCm"]*nhl["HtInCm"]
nhl["BMI"] = nhl["Wt"]*nhl["HtInCm^2"]
del nhl['WtInKg']
del nhl['HtInCm']
del nhl['HtInCm^2']

#adding adjusted +/-
nhl["Adjusted +/-"] = nhl["+/-"]-nhl["E+/-"]

#adding penatlties (in minutes) per game
nhl["PIM/GP"] = nhl["PIM"]/nhl["GP"]

#adding unblocked shot attempts (Fenwick, USAT) taken by this individual per game
nhl["iFF/GP"] = nhl["iFF"]/nhl["GP"]

#adding shots on goal taken by this individual per game
nhl["iSF/GP"] = nhl["iSF"]/nhl["GP"]

#adding expected goals (weighted shots) for this individual per game
nhl["ixG/GP"] = nhl["ixG"]/nhl["GP"]

#adding all scoring chances taken by this individual per game
nhl["iSCF/GP"] = nhl["iSCF"]/nhl["GP"]

#adding an estimate of the player's setup passes (passes that result in a shot attempt) per game
nhl["Pass/GP"] = nhl["Pass"]/nhl["GP"]

#adding hits thrown by this individual per game
nhl["iHF/GP"] = nhl["iHF"]/nhl["GP"]

#adding hits taken by this individual per game
nhl["iHA/GP"] = nhl["iHA"]/nhl["GP"]

#adding individual shots taken that missed the net per game
nhl["iMiss/GP"] = nhl["iMiss"]/nhl["GP"]

#adding giveaways by this individual per game
nhl["iGVA/GP"] = nhl["iGVA"]/nhl["GP"]

#adding takeaways by this individual per game
nhl["iTKA/GP"] = nhl["iTKA"]/nhl["GP"]

#adding shots blocked by this individual per game
nhl["iBLK/GP"] = nhl["iBLK"]/nhl["GP"]

#adding penalties drawn by this individual per game
nhl["iPEND/GP"] = nhl["iPEND"]/nhl["GP"]

#adding penalties taken by this individual per game
nhl["iPENT/GP"] = nhl["iPENT"]/nhl["GP"]

#adding the team's scoring chances while this player was on the ice per game
nhl["SCF/GP"] = nhl["SCF"]/nhl["GP"]

#adding scoring chances allowed while this player was on the ice per game
nhl["SCA/GP"] = nhl["SCA"]/nhl["GP"]

#adding the team's goals while this player was on the ice
nhl["GF/GP"] = nhl["GF"]/nhl["GP"]

#adding goals allowed while this player was on the ice
nhl["GA/GP"] = nhl["GA"]/nhl["GP"]


#overview of the dataframe
nhl.info

##Prepare data for predicting the value of players

#selecting values of the dataset relevant to the prediction for the player's value
nhlSalaryPrediction = nhl[['Salary', 'age', 'BMI', 'Hand', 'Position', 'GP', 'G/GP', 'A/GP', '+/-', 'Adjusted +/-', 'PIM/GP', 'SH%', 'SV%', 'iFF/GP', 'iSF/GP', 'ixG/GP', 'iSCF/GP', 'Pass/GP', 'iHF/GP', 'iHA/GP', 'iMiss/GP', 'iGVA/GP', 'iTKA/GP', 'iBLK/GP', 'BLK%', 'FO%', '%FOT', 'iPENT/GP', 'iPEND/GP', 'SCF/GP', 'SCA/GP', 'GF/GP', 'GA/GP']]

#ckecking correlation between the selected stats for the valuation of the players
nhlSalaryPrediction.corr()

#checking wich stats have a correlation >0.7 (risk to distort the prediction model)
c = nhlSalaryPrediction.corr().abs()
s = c.unstack()
s = s[s<1]
s = s[s>0.7]
s.sort_values().drop_duplicates()

#Eliminate too strongly correlated stats to optimize the prediction model
del nhlSalaryPrediction['SCF/GP']
del nhlSalaryPrediction['SCA/GP']
del nhlSalaryPrediction['Adjusted +/-']
del nhlSalaryPrediction['iSF/GP']
del nhlSalaryPrediction['Pass/GP']
del nhlSalaryPrediction['GF/GP']
del nhlSalaryPrediction['ixG/GP']
del nhlSalaryPrediction['iBLK/GP']
del nhlSalaryPrediction['iPENT/GP']
del nhlSalaryPrediction['iFF/GP']

#Convert "Hand" and "Position" to dummy variable
nhlSalaryPrediction = pd.get_dummies(nhlSalaryPrediction, columns=['Hand'], drop_first=True)
nhlSalaryPrediction = pd.get_dummies(nhlSalaryPrediction, columns=['Position'], drop_first=True)

##RANDOM FOREST MODEL ( I ) 

#splitting dataset to training and test dataset
nhl_train, nhl_test = train_test_split(nhlSalaryPrediction, test_size=0.25, random_state=42)

#checking training data
nhl_train

# Create the random forest model
rf_model = RandomForestRegressor(n_estimators=100)

# Train the model using the training data
y = nhl_train["Salary"]
x = nhl_train.loc[:, nhl_train.columns != 'Salary']
rf_model.fit(x, y)

# Use the model to make predictions on the test data
y_test = nhl_test["Salary"]
X_test = nhl_test.loc[:, nhl_test.columns != 'Salary']
prediction_Salary_test = rf_model.predict(X_test)

# Calculate RMSE
rmse = sqrt(mean_squared_error(y_test, prediction_Salary_test))

#List of metric names
metric_names = ["R-squared", "MAE", "MSE"]

#List of metric functions
metric_functions = [metrics.r2_score, metrics.mean_absolute_error, metrics.mean_squared_error]

#Print summary statistics for your random forest model
print(f"RMSE: {rmse}")
for metric_name, metric_function in zip(metric_names, metric_functions):
  value = metric_function(y_test, prediction_Salary_test)
  print(f"{metric_name}: {value:.4f}")
    
# print the importance of each feature
importances = rf_model.feature_importances_
for i, importance in enumerate(importances):
    feature_name = nhl_train.columns[i]
    print("Feature %s: %f" % (feature_name, importance))

# Create the actual vs. predicted plot
def actual_vs_predicted_plot(y_test, prediction_Salary_test):
  min_value=np.array([y_test.min(), prediction_Salary_test.min()]).min()
  max_value=np.array([y_test.max(), prediction_Salary_test.max()]).max()
  fig, ax = plt.subplots(figsize=(10,5))
  ax.scatter(y_test,prediction_Salary_test, color="blue")
  ax.plot([min_value,max_value], [min_value, max_value], lw=4, color="green")
  ax.set_title("Actual vs Predicted Plot")
  ax.set_xlabel('Actual')
  ax.set_ylabel('Predicted')
  plt.show()

# Display the actual vs. predicted plot
actual_vs_predicted_plot(y_test, prediction_Salary_test)

##RANDOM FOREST MODEL ( II ) 

#Create a variable for the logarithmized salary
nhlSalaryPrediction_log = nhlSalaryPrediction.copy()
nhlSalaryPrediction_log["logSalary"] = np.log(nhlSalaryPrediction["Salary"])
del nhlSalaryPrediction_log["Salary"]

#splitting dataset to training and test dataset
nhl_train_log, nhl_test_log = train_test_split(nhlSalaryPrediction_log, test_size=0.25, random_state=42)

#checking training dataset
nhl_train_log

# Create the random forest model
rf_log_model = RandomForestRegressor(n_estimators=100)

# Train the model using the training data
y = nhl_train_log["logSalary"]
x = nhl_train_log.loc[:, nhl_train_log.columns != 'logSalary']
rf_log_model.fit(x, y)

# Use the model to make predictions on the test data
y_test = nhl_test_log["logSalary"]
X_test = nhl_test_log.loc[:, nhl_test_log.columns != 'logSalary']
predictions_Salary_with_log = rf_log_model.predict(X_test)

#calculate RMSE
rmse_log_sal = sqrt(mean_squared_error(y_test, predictions_Salary_with_log))
print(f"RMSE: {rmse_log_sal}")
for metric_name, metric_function in zip(metric_names, metric_functions):
  value = metric_function(y_test, predictions_Salary_with_log)
  print(f"{metric_name}: {value:.4f}")

# print the importance of each feature
importances = rf_log_model.feature_importances_
for i, importance in enumerate(importances):
    feature_name = nhl_train_log.columns[i]
    print("Feature %s: %f" % (feature_name, importance))
    
#Creating an Actual vs. Predicted Plot
def actual_vs_predicted_plot(y_test, prediction_Salary_test):
  min_value=np.array([y_test.min(), predictions_Salary_with_log.min()]).min()
  max_value=np.array([y_test.max(), predictions_Salary_with_log.max()]).max()
  fig, ax = plt.subplots(figsize=(10,5))
  ax.scatter(y_test,predictions_Salary_with_log, color="blue")
  ax.plot([min_value,max_value], [min_value, max_value], lw=4, color="green")
  ax.set_title("Actual vs Predicted Plot")
  ax.set_xlabel('Actual')
  ax.set_ylabel('Predicted')
  plt.show()

#Displaying Actual vs. Predicted Plot
actual_vs_predicted_plot(y_test, predictions_Salary_with_log)

##Comparison of the two models

# Summary of Results

#|Model|RMSE|R-squared|
#|--|--|--|
#|Linear regression|1879149.1983700546|0.709|
#|Linear regression with logarythmic salary|1854443.3967667823|0.710|

# The model should not predict negative wages -> We will use the model with logarithmic wages for predicting player values. Also, this model has a slightly higher R squared value and a lower RMSE.

##checking smallest predicted salaries for first model

# Convert the predictions array to a pandas series
predictions_Salary_with_log = pd.Series(predictions_Salary_with_log)

# Find the 5 smallest predicted salaries

predictions_Salary_with_log.nsmallest(5)

##checking smallest predicted salaries for second model

# Convert the predictions array to a pandas series
prediction_Salary_test = pd.Series(prediction_Salary_test)

# Find the 5 smallest predicted salaries
prediction_Salary_test.nsmallest(5)

##Determine the effective values of the players (wages they should receive based on their statistics)

#Predicting the salary for the entire dataset / for all players (RF with log salaries)

#creating varibale for logarithm of salary
nhlFinalSalaryPrediction = nhlSalaryPrediction.copy()
nhlFinalSalaryPrediction["logSalary"] = np.log(nhlFinalSalaryPrediction["Salary"])
del nhlFinalSalaryPrediction["Salary"]

#Predicting salary (value of players)
y = nhlFinalSalaryPrediction["logSalary"]
X = nhlFinalSalaryPrediction.loc[:, nhlFinalSalaryPrediction.columns != 'logSalary']
predictions_Salary = rf_log_model.predict(X)
predictions_Salary_final = np.exp(predictions_Salary)
predictions_Salary_final

#adding Value of Players (predicted Salaries based on their stats) and the difference in valuation (overpaid or underpaid) to the main dataset
nhlFinal=nhl.copy()
nhlFinal["Player Value"] = predictions_Salary_final
nhlFinal["Difference in valuation"] = nhlFinal["Player Value"] - nhlFinal["Salary"]

#Overview of final dataset
nhlFinal

#Write nhlFinal dataframe to a CSV file
nhlFinal.to_csv("nhl_final.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 874 entries, 0 to 873
# Columns: 154 entries, Salary to GS/G
# dtypes: float64(73), int64(71), object(10)
# memory usage: 1.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 522 entries, 0 to 873
# Columns: 154 entries, Salary to GS/G
# dtypes: float64(73), int64(71), object(10)
# memory usage: 632.1+ KB
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl['YearBorn'] = np.select(conditions, choices)
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["age"] = 2022 - nhl['YearBorn']
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["WtInKg"] = nhl["Wt"]*0.453592
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["HtInCm"] = nhl["Ht"]*2.54
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["HtInCm^2"] = nhl["HtInCm"]*nhl["HtInCm"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["BMI"] = nhl["Wt"]*nhl["HtInCm^2"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["Adjusted +/-"] = nhl["+/-"]-nhl["E+/-"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["PIM/GP"] = nhl["PIM"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["iFF/GP"] = nhl["iFF"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["iSF/GP"] = nhl["iSF"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:68: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["ixG/GP"] = nhl["ixG"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:71: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["iSCF/GP"] = nhl["iSCF"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:74: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["Pass/GP"] = nhl["Pass"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:77: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["iHF/GP"] = nhl["iHF"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["iHA/GP"] = nhl["iHA"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["iMiss/GP"] = nhl["iMiss"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:86: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["iGVA/GP"] = nhl["iGVA"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["iTKA/GP"] = nhl["iTKA"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["iBLK/GP"] = nhl["iBLK"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:95: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["iPEND/GP"] = nhl["iPEND"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:98: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["iPENT/GP"] = nhl["iPENT"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:101: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["SCF/GP"] = nhl["SCF"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:104: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["SCA/GP"] = nhl["SCA"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:107: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["GF/GP"] = nhl["GF"]/nhl["GP"]
# /var/folders/bq/wzm16xdj7h569f3g4wq1zykr0000gn/T/ipykernel_40175/1496878418.py:110: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nhl["GA/GP"] = nhl["GA"]/nhl["GP"]
# RMSE: 1442470.5457946125
# R-squared: 0.6166
# MAE: 1014742.5185
# MSE: 2080721275485.0071
# Feature Salary: 0.113210
# Feature age: 0.025851
# Feature BMI: 0.062868
# Feature GP: 0.029873
# Feature G/GP: 0.361085
# Feature A/GP: 0.018187
# Feature +/-: 0.014196
# Feature PIM/GP: 0.015291
# Feature SH%: 0.015697
# Feature SV%: 0.024540
# Feature iSCF/GP: 0.018091
# Feature iHF/GP: 0.018336
# Feature iHA/GP: 0.087234
# Feature iMiss/GP: 0.042259
# Feature iGVA/GP: 0.011885
# Feature iTKA/GP: 0.017069
# Feature BLK%: 0.012836
# Feature FO%: 0.025158
# Feature %FOT: 0.013353
# Feature iPEND/GP: 0.057221
# Feature GA/GP: 0.003554
# Feature Hand_R: 0.000000
# Feature Position_C/D: 0.000420
# Feature Position_C/LW: 0.000000
# Feature Position_C/LW/C: 0.002838
# Feature Position_C/LW/RW: 0.000113
# Feature Position_C/RW: 0.000144
# Feature Position_C/RW/LW: 0.000893
# Feature Position_D: 0.000006
# Feature Position_D/RW: 0.001746
# Feature Position_LW: 0.000760
# Feature Position_LW/C: 0.001007
# Feature Position_LW/C/RW: 0.000050
# Feature Position_LW/RW: 0.000131
# Feature Position_LW/RW/C: 0.000981
# Feature Position_RW: 0.002885
# Feature Position_RW/C: 0.000005
# Feature Position_RW/C/LW: 0.000213
# Feature Position_RW/LW: 0.000013
# RMSE: 0.5421734900831593
# R-squared: 0.6173
# MAE: 0.4240
# MSE: 0.2940
# Feature age: 0.110653
# Feature BMI: 0.029962
# Feature GP: 0.245847
# Feature G/GP: 0.031544
# Feature A/GP: 0.210615
# Feature +/-: 0.022707
# Feature PIM/GP: 0.014450
# Feature SH%: 0.012039
# Feature SV%: 0.011670
# Feature iSCF/GP: 0.016102
# Feature iHF/GP: 0.019720
# Feature iHA/GP: 0.015233
# Feature iMiss/GP: 0.065096
# Feature iGVA/GP: 0.050076
# Feature iTKA/GP: 0.014661
# Feature BLK%: 0.014249
# Feature FO%: 0.006645
# Feature %FOT: 0.010892
# Feature iPEND/GP: 0.012248
# Feature GA/GP: 0.072118
# Feature Hand_R: 0.002546
# Feature Position_C/D: 0.000000
# Feature Position_C/LW: 0.000959
# Feature Position_C/LW/C: 0.000000
# Feature Position_C/LW/RW: 0.000445
# Feature Position_C/RW: 0.000032
# Feature Position_C/RW/LW: 0.000332
# Feature Position_D: 0.000487
# Feature Position_D/RW: 0.000001
# Feature Position_LW: 0.003219
# Feature Position_LW/C: 0.001108
# Feature Position_LW/C/RW: 0.001085
# Feature Position_LW/RW: 0.000200
# Feature Position_LW/RW/C: 0.000246
# Feature Position_RW: 0.001479
# Feature Position_RW/C: 0.000643
# Feature Position_RW/C/LW: 0.000258
# Feature Position_RW/LW: 0.000242
# Feature Position_RW/LW/C: 0.000190
